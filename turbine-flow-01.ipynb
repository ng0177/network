# %% [markdown]
# <a href="https://colab.research.google.com/github/ng0177/network/blob/main/nonlinear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Non linear regression / curve fitting
#
# You'll find more information and detailed explainations on [my blog](https://lucidar.me/en/neural-networks/curve-fitting-nonlinear-regression/).
#
# [Video of the expected result](https://youtu.be/7z86Lxzf_2o)

# %% [markdown]
# ## Check/install TensorFlow version
# **Must be version 2.1.0**

# %%
# Switch the TensorFlow version 2.1
#!pip install tensorflow==2.1.0

# %% [markdown]
# ## Import libraries and create noisy data

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
#from google.colab import files
import tensorflow as tf
import math

print ('TensorFlow version: ' + tf.__version__)

# Create noisy data
#x_data = np.linspace(-10, 10, num=1000)
#y_data = 0.1 * x_data * np.cos(x_data) + 0.1 * np.random.normal(size=1000)
print('Data created successfully')
x_data = np.array([[ 1.27305],[ 1.30392],[ 1.34063],[ 1.38482],[ 1.43878],[ 1.50577],[ 1.59061],[ 1.70066],[ 1.84776],[ 2.05185],[ 2.34924],[ 2.81181],[ 3.60117],[ 5.14998]])
y_data = np.array([[ 1.34714],[ 1.41808],[ 1.47987],[ 1.55098],[ 1.62026],[ 1.69219],[ 1.76749],[ 1.83998],[ 1.91347],[ 1.98128],[ 2.04018],[ 2.08743],[ 2.12260],[ 2.14005]])
# Out:
# TensorFlow version: 2.9.1
# Data created successfully

# %% [markdown]
# ## Display curve to fit

# %%
# Display the dataset
plt.scatter(x_data[::1], y_data[::1], s=50)
plt.grid()
plt.show()
plt.savefig('dataset.png',dpi=300)
#files.download('dataset.png')

# %% [markdown]
# # Create the model
# Create the model with two 64 units hidden layers.

# %%
# Create the model 
model = keras.Sequential()
model.add(keras.layers.Dense(units=128,input_shape=(1,), activation='relu'))
model.add(keras.layers.Dense(64, activation='relu'))
model.add(keras.layers.Dense(32, activation='relu'))
model.add(keras.layers.Dense(16, activation='relu'))
model.add(keras.layers.Dense(1,))
model.compile(optimizer='adam',loss = 'mae')

# Display the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               256
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 16)                528
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 11,137
# Trainable params: 11,137
# Non-trainable params: 0
# _________________________________________________________________
# 2022-08-20 08:48:13.841710: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-20 08:48:13.860294: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-20 08:48:13.860403: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-20 08:48:13.860917: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-20 08:48:13.861912: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-20 08:48:13.862008: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-20 08:48:13.862080: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-20 08:48:14.093913: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-20 08:48:14.094061: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-20 08:48:14.094142: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-20 08:48:14.094201: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:222] Using CUDA malloc Async allocator for GPU: 0
# 2022-08-20 08:48:14.094271: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 3775 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1060 6GB, pci bus id: 0000:01:00.0, compute capability: 6.1
# 2022-08-20 08:48:14.094451: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %% [markdown]
# ## Training over 100 epochs

# %%
# Training
model.fit(x_data, y_data,epochs=300, batch_size=64)
# Out:
# Epoch 1/300
# 1/1 [==============================] - 1s 592ms/step - loss: 1.8661
# Epoch 2/300
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8348
# Epoch 3/300
# 1/1 [==============================] - 0s 3ms/step - loss: 1.8213
# Epoch 4/300
# 1/1 [==============================] - 0s 2ms/step - loss: 1.
300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2409
# Epoch 117/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2383
# Epoch 118/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2369
# Epoch 119/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2358
# Epoch 120/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2330
# Epoch 121/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2316
# Epoch 122/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2301
# Epoch 123/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2279
# Epoch 124/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2268
# Epoch 125/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2249
# Epoch 126/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2234
# Epoch 127/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2219
# Epoch 128/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2204
# Epoch 129/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2189
# Epoch 130/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2174
# Epoch 131/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.2158
# Epoch 132/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2143
# Epoch 133/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2127
# Epoch 134/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2111
# Epoch 135/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2095
# Epoch 136/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2078
# Epoch 137/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2061
# Epoch 138/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2038
# Epoch 139/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2010
# Epoch 140/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1973
# Epoch 141/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1946
# Epoch 142/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1929
# Epoch 143/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1909
# Epoch 144/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1890
# Epoch 145/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1865
# Epoch 146/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1843
# Epoch 147/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1819
# Epoch 148/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1795
# Epoch 149/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1770
# Epoch 150/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1744
# Epoch 151/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1717
# Epoch 152/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1697
# Epoch 153/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1682
# Epoch 154/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1668
# Epoch 155/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1633
# Epoch 156/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1627
# Epoch 157/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1629
# Epoch 158/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1594
# Epoch 159/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1561
# Epoch 160/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1585
# Epoch 161/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1558
# Epoch 162/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1524
# Epoch 163/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1525
# Epoch 164/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1518
# Epoch 165/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1502
# Epoch 166/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1475
# Epoch 167/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1463
# Epoch 168/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1461
# Epoch 169/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1455
# Epoch 170/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1445
# Epoch 171/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1433
# Epoch 172/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1418
# Epoch 173/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1400
# Epoch 174/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1380
# Epoch 175/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1446
# Epoch 176/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1365
# Epoch 177/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1401
# Epoch 178/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1426
# Epoch 179/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1415
# Epoch 180/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1331
# Epoch 181/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1366
# Epoch 182/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1387
# Epoch 183/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1275
# Epoch 184/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1176
# Epoch 185/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1235
# Epoch 186/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1225
# Epoch 187/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1153
# Epoch 188/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1142
# Epoch 189/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1228
# Epoch 190/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1223
# Epoch 191/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1121
# Epoch 192/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1106
# Epoch 193/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1109
# Epoch 194/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1100
# Epoch 195/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1079
# Epoch 196/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1047
# Epoch 197/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1041
# Epoch 198/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1032
# Epoch 199/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1011
# Epoch 200/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1011
# Epoch 201/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1003
# Epoch 202/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0997
# Epoch 203/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0995
# Epoch 204/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0982
# Epoch 205/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0959
# Epoch 206/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0929
# Epoch 207/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0929
# Epoch 208/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0910
# Epoch 209/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0867
# Epoch 210/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0873
# Epoch 211/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0875
# Epoch 212/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0834
# Epoch 213/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0810
# Epoch 214/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0786
# Epoch 215/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0881
# Epoch 216/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0817
# Epoch 217/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0815
# Epoch 218/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0770
# Epoch 219/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0871
# Epoch 220/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0812
# Epoch 221/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0762
# Epoch 222/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0832
# Epoch 223/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0776
# Epoch 224/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0882
# Epoch 225/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0746
# Epoch 226/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0838
# Epoch 227/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0762
# Epoch 228/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0844
# Epoch 229/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0761
# Epoch 230/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0737
# Epoch 231/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0730
# Epoch 232/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0767
# Epoch 233/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0768
# Epoch 234/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0727
# Epoch 235/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0752
# Epoch 236/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0770
# Epoch 237/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0709
# Epoch 238/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0721
# Epoch 239/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0848
# Epoch 240/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0795
# Epoch 241/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0844
# Epoch 242/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0842
# Epoch 243/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0746
# Epoch 244/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0736
# Epoch 245/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0808
# Epoch 246/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0761
# Epoch 247/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0814
# Epoch 248/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0846
# Epoch 249/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0691
# Epoch 250/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0754
# Epoch 251/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0689
# Epoch 252/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0797
# Epoch 253/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0725
# Epoch 254/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0842
# Epoch 255/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0842
# Epoch 256/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0689
# Epoch 257/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0703
# Epoch 258/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0757
# Epoch 259/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0692
# Epoch 260/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0834
# Epoch 261/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0862
# Epoch 262/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0698
# Epoch 263/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0927
# Epoch 264/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1027
# Epoch 265/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0842
# Epoch 266/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0774
# Epoch 267/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0901
# Epoch 268/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0860
# Epoch 269/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0675
# Epoch 270/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0763
# Epoch 271/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0710
# Epoch 272/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0770
# Epoch 273/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0814
# Epoch 274/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0704
# Epoch 275/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0816
# Epoch 276/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0863
# Epoch 277/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0687
# Epoch 278/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0748
# Epoch 279/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0770
# Epoch 280/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0666
# Epoch 281/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0708
# Epoch 282/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0662
# Epoch 283/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0679
# Epoch 284/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0660
# Epoch 285/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0667
# Epoch 286/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0650
# Epoch 287/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0647
# Epoch 288/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0646
# Epoch 289/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0653
# Epoch 290/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0726
# Epoch 291/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0691
# Epoch 292/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0720
# Epoch 293/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0727
# Epoch 294/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0643
# Epoch 295/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0742
# Epoch 296/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0636
# Epoch 297/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0691
# Epoch 298/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0632
# Epoch 299/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0773
# Epoch 300/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0799

# %% [markdown]
# # Predict and display

# %%
# Compute the output 
y_predicted = model.predict(x_data)

# Display the result
plt.scatter(x_data[::1], y_data[::1], s=50)
plt.plot(x_data, y_predicted, 'r', linewidth=3)
plt.grid()
#plt.show()
plt.savefig('training.png', dpi=300)
#files.download("training.png")
# Out:
# 1/1 [==============================] - 0s 42ms/step

# %% [markdown]
# ## Create image sequence for the video
#
# Run this section to generate a sequence of images for the [video](https://www.youtube.com/watch?v=7z86Lxzf_2o).
#
# To get the video from the beginning, you have to reset the model weight. Re-creating the model should reseting the weights.

# %%
#for x in range(100):
#  # One epoch
#  model.fit( x_data, y_data, epochs=1, verbose=1)
#
#  # Compute the output 
#  y_predicted = model.predict(x_data)
#
#  # Display the result
#  plt.scatter(x_data[::1], y_data[::1], s=2)
#  plt.plot(x_data, y_predicted, 'r', linewidth=4)
#  plt.grid()
#  plt.ylim(top=1.2)  # adjust the top leaving bottom unchanged
#  plt.ylim(bottom=-1.2)  
#  #plt.show()
#  plt.savefig('training-' + str(x) +'-epochs.png',dpi=300)
#  #files.download('training-' + str(x) +'-epochs.png') 
#  plt.clf()
