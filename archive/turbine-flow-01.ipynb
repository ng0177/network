# %% [markdown]
# <a href="https://colab.research.google.com/github/ng0177/network/blob/main/nonlinear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Non linear regression / curve fitting
#
# You'll find more information and detailed explainations on [my blog](https://lucidar.me/en/neural-networks/curve-fitting-nonlinear-regression/).
#
# [Video of the expected result](https://youtu.be/7z86Lxzf_2o)

# %% [markdown]
# ## Check/install TensorFlow version
# **Must be version 2.1.0**

# %%
# Switch the TensorFlow version 2.1
#!pip install tensorflow==2.1.0

# %% [markdown]
# ## Import libraries and create noisy data

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
#from google.colab import files
import tensorflow as tf
import math

print ('TensorFlow version: ' + tf.__version__)

# Create noisy data
#x_data = np.linspace(-10, 10, num=1000)
#y_data = 0.1 * x_data * np.cos(x_data) + 0.1 * np.random.normal(size=1000)
print('Data created successfully')
x_data = np.array([[ 1.27305],[ 1.30392],[ 1.34063],[ 1.38482],[ 1.43878],[ 1.50577],[ 1.59061],[ 1.70066],[ 1.84776],[ 2.05185],[ 2.34924],[ 2.81181],[ 3.60117],[ 5.14998]])
y_data = np.array([[ 1.34714],[ 1.41808],[ 1.47987],[ 1.55098],[ 1.62026],[ 1.69219],[ 1.76749],[ 1.83998],[ 1.91347],[ 1.98128],[ 2.04018],[ 2.08743],[ 2.12260],[ 2.14005]])

x_data = MinMaxScaler().fit_transform(x_data)
y_data = MinMaxScaler().fit_transform(y_data)
# Out:
# TensorFlow version: 2.9.1
# Data created successfully

# %% [markdown]
# ## Display curve to fit

# %%
# Display the dataset
plt.scatter(x_data[::1], y_data[::1], s=50)
plt.grid()
plt.show()
plt.savefig('dataset.png',dpi=300)
#files.download('dataset.png')

# %% [markdown]
# # Create the model
# Create the model with two 64 units hidden layers.

# %%
# Create the model 
model = keras.Sequential()
model.add(keras.layers.Dense(units=128,input_shape=(1,), activation='relu'))
model.add(keras.layers.Dense(64, activation='relu'))
model.add(keras.layers.Dense(32, activation='relu'))
model.add(keras.layers.Dense(16, activation='relu'))
model.add(keras.layers.Dense(1,))
model.compile(optimizer='adam',loss = 'mae')

# Display the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               256
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 32)                2080
#
#  dense_3 (Dense)             (None, 16)                528
#
#  dense_4 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 11,137
# Trainable params: 11,137
# Non-trainable params: 0
# _________________________________________________________________
# 2022-08-20 12:09:16.360014: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-20 12:09:16.379692: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-20 12:09:16.379813: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-20 12:09:16.380342: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-08-20 12:09:16.381383: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-20 12:09:16.381564: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-20 12:09:16.381639: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-20 12:09:16.601751: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-20 12:09:16.601879: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-20 12:09:16.601961: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-20 12:09:16.602019: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:222] Using CUDA malloc Async allocator for GPU: 0
# 2022-08-20 12:09:16.602091: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2464 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1060 6GB, pci bus id: 0000:01:00.0, compute capability: 6.1
# 2022-08-20 12:09:16.602556: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %% [markdown]
# ## Training over 100 epochs

# %%
# Training
model.fit(x_data, y_data,epochs=300, batch_size=64)
# Out:
# Epoch 1/300
# 1/1 [==============================] - 0s 457ms/step - loss: 0.5579
# Epoch 2/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5483
# Epoch 3/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.5429
# Epoch 4/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5387
# Epoch 5/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5338
# Epoch 6/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5289
# Epoch 7/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5235
# Epoch 8/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5176
# Epoch 9/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5112
# Epoch 10/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.5044
# Epoch 11/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4973
# Epoch 12/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4897
# Epoch 13/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4817
# Epoch 14/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4733
# Epoch 15/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4645
# Epoch 16/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4550
# Epoch 17/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4451
# Epoch 18/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4345
# Epoch 19/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4246
# Epoch 20/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4142
# Epoch 21/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.4032
# Epoch 22/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3917
# Epoch 23/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3795
# Epoch 24/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3666
# Epoch 25/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3531
# Epoch 26/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3399
# Epoch 27/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3266
# Epoch 28/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3127
# Epoch 29/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2980
# Epoch 30/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2824
# Epoch 31/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2660
# Epoch 32/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2509
# Epoch 33/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2352
# Epoch 34/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.2186
# Epoch 35/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.
300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0258
# Epoch 184/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0197
# Epoch 185/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0217
# Epoch 186/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0165
# Epoch 187/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0204
# Epoch 188/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0150
# Epoch 189/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0209
# Epoch 190/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0176
# Epoch 191/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0176
# Epoch 192/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0129
# Epoch 193/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0177
# Epoch 194/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0116
# Epoch 195/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0212
# Epoch 196/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0166
# Epoch 197/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0171
# Epoch 198/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0126
# Epoch 199/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0194
# Epoch 200/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0232
# Epoch 201/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0185
# Epoch 202/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0101
# Epoch 203/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0139
# Epoch 204/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0131
# Epoch 205/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0086
# Epoch 206/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0099
# Epoch 207/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0075
# Epoch 208/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0127
# Epoch 209/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0118
# Epoch 210/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0094
# Epoch 211/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0130
# Epoch 212/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0125
# Epoch 213/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0110
# Epoch 214/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0136
# Epoch 215/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0115
# Epoch 216/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 217/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0100
# Epoch 218/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0071
# Epoch 219/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0124
# Epoch 220/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 221/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0079
# Epoch 222/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0145
# Epoch 223/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0172
# Epoch 224/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0082
# Epoch 225/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0135
# Epoch 226/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0193
# Epoch 227/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0163
# Epoch 228/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 229/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0113
# Epoch 230/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0105
# Epoch 231/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0057
# Epoch 232/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0097
# Epoch 233/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0086
# Epoch 234/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 235/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0100
# Epoch 236/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0051
# Epoch 237/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0064
# Epoch 238/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0051
# Epoch 239/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0086
# Epoch 240/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0064
# Epoch 241/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0065
# Epoch 242/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 243/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0073
# Epoch 244/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 245/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0133
# Epoch 246/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0059
# Epoch 247/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0185
# Epoch 248/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0178
# Epoch 249/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0138
# Epoch 250/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0170
# Epoch 251/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0068
# Epoch 252/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0211
# Epoch 253/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0263
# Epoch 254/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0126
# Epoch 255/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0205
# Epoch 256/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0261
# Epoch 257/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0133
# Epoch 258/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0155
# Epoch 259/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0207
# Epoch 260/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0115
# Epoch 261/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0129
# Epoch 262/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0130
# Epoch 263/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 264/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0125
# Epoch 265/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0060
# Epoch 266/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0125
# Epoch 267/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 268/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0091
# Epoch 269/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0082
# Epoch 270/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0088
# Epoch 271/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0084
# Epoch 272/300
# 1/1 [==============================] - 0s 3ms/step - loss: 0.0074
# Epoch 273/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0048
# Epoch 274/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0058
# Epoch 275/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0047
# Epoch 276/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0053
# Epoch 277/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0055
# Epoch 278/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0054
# Epoch 279/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0043
# Epoch 280/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0055
# Epoch 281/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0032
# Epoch 282/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0081
# Epoch 283/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0079
# Epoch 284/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0033
# Epoch 285/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0092
# Epoch 286/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0101
# Epoch 287/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0050
# Epoch 288/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0093
# Epoch 289/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0118
# Epoch 290/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0086
# Epoch 291/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0044
# Epoch 292/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0067
# Epoch 293/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0034
# Epoch 294/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0125
# Epoch 295/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0129
# Epoch 296/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0101
# Epoch 297/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 298/300
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 299/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0073
# Epoch 300/300
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0046

# %% [markdown]
# # Predict and display

# %%
# Compute the output 
y_predicted = model.predict(x_data)

# Display the result
plt.scatter(x_data[::1], y_data[::1], s=50)
plt.plot(x_data, y_predicted, 'r', linewidth=3)
plt.grid()
#plt.show()
plt.savefig('training.png', dpi=300)
#files.download("training.png")
# Out:
# 1/1 [==============================] - 0s 105ms/step

# %% [markdown]
# ## Create image sequence for the video
#
# Run this section to generate a sequence of images for the [video](https://www.youtube.com/watch?v=7z86Lxzf_2o).
#
# To get the video from the beginning, you have to reset the model weight. Re-creating the model should reseting the weights.

# %%
#for x in range(100):
#  # One epoch
#  model.fit( x_data, y_data, epochs=1, verbose=1)
#
#  # Compute the output 
#  y_predicted = model.predict(x_data)
#
#  # Display the result
#  plt.scatter(x_data[::1], y_data[::1], s=2)
#  plt.plot(x_data, y_predicted, 'r', linewidth=4)
#  plt.grid()
#  plt.ylim(top=1.2)  # adjust the top leaving bottom unchanged
#  plt.ylim(bottom=-1.2)  
#  #plt.show()
#  plt.savefig('training-' + str(x) +'-epochs.png',dpi=300)
#  #files.download('training-' + str(x) +'-epochs.png') 
#  plt.clf()
